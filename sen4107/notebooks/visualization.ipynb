# %% [markdown]
# # Turkish Speech Emotion Recognition - Visualization Notebook
# # Türkçe Konuşma Duygu Tanıma - Görselleştirme Defteri
#
# **SEN4107 Neural Networks Course Project**
#
# This notebook provides comprehensive visualizations and analysis for the Turkish Speech Emotion Recognition project, comparing two different architectures:
# - **Model 1 (Baseline)**: CNN operating on log-mel spectrograms
# - **Model 2 (Comparison)**: CNN + BiLSTM hybrid architecture
#
# ---
#
# ## Table of Contents / İçindekiler
#
# 1. Setup and Imports
# 2. Dataset Exploration
# 3. Audio Waveform and Spectrogram Visualization
# 4. Feature Distribution Analysis
# 5. Model Architecture Comparison
# 6. Training Curves Visualization
# 7. Performance Metrics and Confusion Matrix
# 8. Error Analysis
# 9. Conclusions
#
# ---
